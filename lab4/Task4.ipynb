# %% [markdown]
# ### **Перевірка даних на нормальність за допомогою критерію Шапіра-Уілка**

# %% [markdown]
#
#
# <h1>1.</h1>   Сгенеруйте набір даних, що містить не менше 6 змінних. Частину змінних згенеруйте за нормальний розподілом, частину - за будь-яким іншим розподілом. Кількість спостережень - 20.

# %%
import pandas as pd
import numpy as np
import scipy.stats as sts

# %%
df = pd.DataFrame({
    'gammaD': np.random.gamma(shape=1, size=20),
    'normalD1': np.random.normal(loc=10, scale=5, size=20),
    'geometricD': np.random.geometric(p=0.5, size=20),
    'uniformD': np.random.uniform(size=20),
    'normalD2': np.random.normal(loc=5, scale=10, size=20),
    'normalD3': np.random.randn(20)
})

n=df.shape[0]

df.T
# Out:
#                     0          1         2          3         4          5  \
# gammaD       0.004627   0.299311  0.226102   1.255149  0.801853   1.619911
# normalD1     8.027076  13.600018  7.073236  16.043326  6.782871  11.387392
# geometricD   3.000000   2.000000  5.000000   1.000000  2.000000   1.000000
# uniformD     0.809989   0.942053  0.490960   0.539301  0.722495   0.049278
# normalD2    18.052927 -10.612985  2.742650   4.250390 -6.871773   3.622787
# normalD3     0.981664  -2.061058  1.163659   0.881636 -1.159049  -2.583187
#
#                     6         7          8          9        10         11  \
# gammaD       2.353566  0.474985   0.513287   0.466644  0.670771   0.693266
# normalD1    15.216509  5.211261  15.253849  15.784861  8.284895  13.195323
# geometricD   2.000000  2.000000   2.000000   3.000000  1.000000   1.000000
# uniformD     0.761433  0.842081   0.564816   0.914195  0.612955   0.208841
# normalD2     8.383282  7.649623  -5.844858  19.920778 -5.385151  -8.046928
# normalD3    -0.415586 -0.760017   0.351311   0.514354 -2.403265   0.283200
#
#                   12         13        14        15         16        17  \
# gammaD      0.609989   1.282334  0.304486  1.570811   1.251014  1.136404
# normalD1    7.755229  10.369077  4.875932  8.067808  10.014918  8.988701
# geometricD  2.000000   2.000000  2.000000  5.000000   2.000000  3.000000
# uniformD    0.452874   0.317061  0.065950  0.945016   0.208473  0.144865
# normalD2   -3.892861  17.848983 -4.020749 -0.247464  -5.683792 -1.176041
# normalD3    0.145328  -1.495976 -0.076432 -1.215208   0.364265  0.023996
#
#                    18         19
# gammaD       0.236485   0.967594
# normalD1     8.209875  13.349369
# geometricD   1.000000   4.000000
# uniformD     0.821380   0.460123
# normalD2    13.662060 -11.998310
# normalD3    -2.673278  -1.562388

# %% [markdown]
# <h1>2.</h1>   Створіть функцію, що реалізує критерій Шапіро-Уілка та застосуйте її до кожної змінної набору данних.
# Детальний опис роботи критерію та приклад його розрахунку:
# https://pdfs.semanticscholar.org/e4a7/42a4f0585b4e4069726f6628f4d4285a0827.pdf

# %%
# 1. Ordering the observation
# df.sort_values(['gammaD', 'geometricD'], inplace=True)

df = pd.DataFrame({key: sorted(values) for key, values in df.transpose().iterrows()})
df.T
# Out:
#                     0          1         2         3         4         5  \
# gammaD       0.004627   0.226102  0.236485  0.299311  0.304486  0.466644
# normalD1     4.875932   5.211261  6.782871  7.073236  7.755229  8.027076
# geometricD   1.000000   1.000000  1.000000  1.000000  1.000000  2.000000
# uniformD     0.049278   0.065950  0.144865  0.208473  0.208841  0.317061
# normalD2   -11.998310 -10.612985 -8.046928 -6.871773 -5.844858 -5.683792
# normalD3    -2.673278  -2.583187 -2.403265 -2.061058 -1.562388 -1.495976
#
#                    6         7         8         9         10         11  \
# gammaD      0.474985  0.513287  0.609989  0.670771   0.693266   0.801853
# normalD1    8.067808  8.209875  8.284895  8.988701  10.014918  10.369077
# geometricD  2.000000  2.000000  2.000000  2.000000   2.000000   2.000000
# uniformD    0.452874  0.460123  0.490960  0.539301   0.564816   0.612955
# normalD2   -5.385151 -4.020749 -3.892861 -1.176041  -0.247464   2.742650
# normalD3   -1.215208 -1.159049 -0.760017 -0.415586  -0.076432   0.023996
#
#                    12         13         14         15         16         17  \
# gammaD       0.967594   1.136404   1.251014   1.255149   1.282334   1.570811
# normalD1    11.387392  13.195323  13.349369  13.600018  15.216509  15.253849
# geometricD   2.000000   2.000000   3.000000   3.000000   3.000000   4.000000
# uniformD     0.722495   0.761433   0.809989   0.821380   0.842081   0.914195
# normalD2     3.622787   4.250390   7.649623   8.383282  13.662060  17.848983
# normalD3     0.145328   0.283200   0.351311   0.364265   0.514354   0.881636
#
#                    18         19
# gammaD       1.619911   2.353566
# normalD1    15.784861  16.043326
# geometricD   5.000000   5.000000
# uniformD     0.942053   0.945016
# normalD2    18.052927  19.920778
# normalD3     0.981664   1.163659

# %%
# 2. Variance S²
def get_data_mean(array):
    return sum(array)/n

def get_data_squared_S(array, data_mean):
    return sum([(array[i]-data_mean)**2 for i in range(n)]) 

data_mean = {dist: get_data_mean(df[dist]) for dist in df}
data_squared_S = {dist: get_data_squared_S(df[dist], data_mean[dist])
                 for dist in df}

# %%
# 3. Compute b

a=[0.4734, 0.3211, 0.2565, 0.2085, 0.1686, 0.1334, 0.1013, 0.0711, 0.0422, 0.0140]

def get_b(array):
    return sum([a[i]*(array[(n-1)-i]-array[i])
                for i in range(n//2)])

data_b = {dist: get_b(df[dist]) for dist in df}

# %%
# 4. Compute W

def calculate_W(b, squared_S):
    return b**2/squared_S

data_W = {dist: calculate_W(data_b[dist], data_squared_S[dist]) for dist in df}

WTheory = sts.shapiro(df['normalD3'])
data_W, WTheory
# Out:
# ({'gammaD': 0.93480450334303,
#   'normalD1': 0.924890212640973,
#   'geometricD': 0.8290139010638298,
#   'uniformD': 0.9303876952845006,
#   'normalD2': 0.9238330580308596,
#   'normalD3': 0.9311261250505309},
#  (0.9311025738716125, 0.16214603185653687))

# %% [markdown]
# <h1>3.</h1> Сгенеруйте пусту таблицю, в якій кількість рядків - це кількість змінних + 1. Кількість стовбчиків - 3. Назва стовпчиків - Variable, Statistics, Distribution.
# Шаблон таблиці:
# https://drive.google.com/file/d/1gRNsk9UDhl_6GGkJ04q0cBWBgsJvTgI4/view?usp=sharing

# %%
column_names = ["Variable", "Statistics", "Distribution"]
new_df = pd.DataFrame(columns = column_names)
new_df
# Out:
# Empty DataFrame
# Columns: [Variable, Statistics, Distribution]
# Index: []

# %% [markdown]
# <h1>4.</h1> Занести в стовпчик Variable назви змінних.

# %%
new_df["Variable"] = df.keys()
new_df
# Out:
#      Variable Statistics Distribution
# 0      gammaD        NaN          NaN
# 1    normalD1        NaN          NaN
# 2  geometricD        NaN          NaN
# 3    uniformD        NaN          NaN
# 4    normalD2        NaN          NaN
# 5    normalD3        NaN          NaN

# %% [markdown]
# <h1>5.</h1> Занести в стовпчик Distribution результати роботи криетрію Шапіро-Уілка. Для змінних, які розподілені за нормальним законом вносити "normal", в протилежному вигляді - "non-normal".

# %%
new_df["Distribution"] = [('normal ' if 'normal' in dist else 'non-normal ')+
                          str(data_W[dist])
                          for dist in new_df["Variable"]]
new_df
# Out:
#      Variable Statistics                   Distribution
# 0      gammaD        NaN    non-normal 0.93480450334303
# 1    normalD1        NaN       normal 0.924890212640973
# 2  geometricD        NaN  non-normal 0.8290139010638298
# 3    uniformD        NaN  non-normal 0.9303876952845006
# 4    normalD2        NaN      normal 0.9238330580308596
# 5    normalD3        NaN      normal 0.9311261250505309

# %% [markdown]
# <h1>6.</h1> Розрахувати для всіх змінних, що розподілені за нормальним законом розрахувати середне значення та стандартне відхилення. Записати в таблицю. Форма запису: Середнє [стандартне відхилення].

# %%
for i in range (new_df.shape[0]):
    current_variable = new_df["Variable"][i]
    if 'normal' in current_variable:
        new_df["Statistics"][i] = f'{df[current_variable].mean()} [{df[current_variable].std()}]'

new_df
# Out:
#      Variable                               Statistics  \
# 0      gammaD                                      NaN
# 1    normalD1  10.374576392663512 [3.6010419262260425]
# 2  geometricD                                      NaN
# 3    uniformD                                      NaN
# 4    normalD2    1.617628341155687 [9.840731463064953]
# 5    normalD3  -0.584801469340495 [1.2349296318525602]
#
#                     Distribution
# 0    non-normal 0.93480450334303
# 1       normal 0.924890212640973
# 2  non-normal 0.8290139010638298
# 3  non-normal 0.9303876952845006
# 4      normal 0.9238330580308596
# 5      normal 0.9311261250505309

# %% [markdown]
# <h1>7.</h1> Розрахувати для всіх змінних, що розподілені за розподілом відсутнім від нормального розрахувати медіану та інтерквартильний розмах. Записати в таблицю. Форма запису: Медіана [25%; 75%].

# %%
for i in range (new_df.shape[0]):
    current_variable = new_df["Variable"][i]
    if 'normal' not in current_variable:
        new_df["Statistics"][i] = \
        f'{df[current_variable].median()} \
        [{df[current_variable].quantile(0.25)}; {df[current_variable].quantile(0.75)}]'

new_df
# Out:
#      Variable                                         Statistics  \
# 0      gammaD  0.6820185532591647         [0.426104537752087;...
# 1    normalD1            10.374576392663512 [3.6010419262260425]
# 2  geometricD                            2.0         [1.75; 3.0]
# 3    uniformD  0.5520584544339667         [0.2900059172394499...
# 4    normalD2              1.617628341155687 [9.840731463064953]
# 5    normalD3            -0.584801469340495 [1.2349296318525602]
#
#                     Distribution
# 0    non-normal 0.93480450334303
# 1       normal 0.924890212640973
# 2  non-normal 0.8290139010638298
# 3  non-normal 0.9303876952845006
# 4      normal 0.9238330580308596
# 5      normal 0.9311261250505309

# %% [markdown]
# <h1>8.</h1> Зберегти таблицю в пдф форматі

# %%
import weasyprint

# %%
HTML_TEMPLATE1 = '''
<html>
<head>
<style>
  h2 {
    text-align: center;
    font-family: Helvetica, Arial, sans-serif;
  }
  table { 
    margin-left: auto;
    margin-right: auto;
  }
  table, th, td {
    border: 1px solid black;
    border-collapse: collapse;
  }
  th, td {
    padding: 5px;
    text-align: center;
    font-family: Helvetica, Arial, sans-serif;
    font-size: 90%;
  }
  table tbody tr:hover {
    background-color: #dddddd;
  }
  .wide {
    width: 90%; 
  }
</style>
</head>
<body>
'''

HTML_TEMPLATE2 = '''
</body>
</html>
'''


def to_html_pretty(dframe, filename='out.html', title=''):
    ht = ''
    if title != '':
        ht += '<h2> %s </h2>\n' % title
    ht += dframe.to_html(classes='wide', escape=False)

    with open(filename, 'w') as f:
         f.write(HTML_TEMPLATE1 + ht + HTML_TEMPLATE2)


intermediate_html = 'intermediate.html'
new_df.to_html(intermediate_html)
to_html_pretty(new_df, intermediate_html, 'Stats')

out_pdf= 'Lab4Stats.pdf'
weasyprint.HTML(intermediate_html).write_pdf(out_pdf)
